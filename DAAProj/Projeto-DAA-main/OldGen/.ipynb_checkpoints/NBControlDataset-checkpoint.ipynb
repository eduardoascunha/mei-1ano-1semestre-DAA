# %% [markdown]
# # Notebook do Grupo23 para o dataset Controlo!

# %% [markdown]
# ## Primeira análise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import imblearn

# %%
control = pd.read_csv("sbsppdaa24/train_radiomics_hipocamp.csv")

# %%
control.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 2181 entries, ID to Transition
# dtypes: float64(2014), int64(147), object(20)
# memory usage: 5.1+ MB

# %%
control.columns
# Out:
# Index(['ID', 'Image', 'Mask', 'diagnostics_Versions_PyRadiomics',
#        'diagnostics_Versions_Numpy', 'diagnostics_Versions_SimpleITK',
#        'diagnostics_Versions_PyWavelet', 'diagnostics_Versions_Python',
#        'diagnostics_Configuration_Settings',
#        'diagnostics_Configuration_EnabledImageTypes',
#        ...
#        'lbp-3D-k_glszm_ZonePercentage', 'lbp-3D-k_glszm_ZoneVariance',
#        'lbp-3D-k_ngtdm_Busyness', 'lbp-3D-k_ngtdm_Coarseness',
#        'lbp-3D-k_ngtdm_Complexity', 'lbp-3D-k_ngtdm_Contrast',
#        'lbp-3D-k_ngtdm_Strength', 'Sex', 'Age', 'Transition'],
#       dtype='object', length=2181)

# %% [markdown]
# ## Drop das primeiras Features

# %%
control['Mask'].unique().size
# Out:
# 305

# %%
control['ID'].unique().size
# Out:
# 305

# %%
control['Image'].unique().size
# Out:
# 305

# %%
control.drop(columns=["Mask","ID","Image"], inplace=True)

# %% [markdown]
# ### Os três atributos são únicos para todas as entradas e não são numéricos.

# %%
# Find and drop columns where all values are the same
columns_to_drop = [col for col in control.columns if control[col].nunique() == 1]

# Drop the columns
control.drop(columns=columns_to_drop, inplace=True)
print(f"Dropped {len(columns_to_drop)} constant columns.")
# Out:
# Dropped 159 constant columns.

# %%
# Drop columns where all values are unique and the column is non-numeric
columns_to_drop = [col for col in control.columns if control[col].dtype == 'object' and control[col].nunique() == len(control)]
columns_to_drop
# Drop the columns
control.drop(columns=columns_to_drop, inplace=True)
print(f"Dropped {len(columns_to_drop)} unique non-numerical columns.")
# Out:
# Dropped 5 unique non-numerical columns.

# %%
# Check for columns that contain the word "Hash" in their name
hash_columns = [col for col in control.columns if 'Hash' in col]

control.drop(columns=hash_columns, inplace=True)
# Print the number of columns that contain "Hash"
print(f"Number of columns containing 'Hash': {len(hash_columns)}")

# Optionally, print the names of these columns
print("Columns containing 'Hash':", hash_columns)
control.head()
# Out:
# Number of columns containing 'Hash': 0
# Columns containing 'Hash': []
#    diagnostics_Image-original_Mean  diagnostics_Image-original_Maximum  \
# 0                         5.848123                                 178
# 1                         5.238834                                 190
# 2                         6.816667                                 155
# 3                         6.445162                                 171
# 4                         5.568269                                 150
#
#    diagnostics_Mask-original_VoxelNum  original_shape_Elongation  \
# 0                                7106                   0.420040
# 1                                7779                   0.425482
# 2                                6707                   0.447685
# 3                                8281                   0.418896
# 4                                5986                   0.411851
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.106547                       10.757474
# 1                 0.102532                       10.432362
# 2                 0.135582                       14.370911
# 3                 0.099626                       10.639815
# 4                 0.080719                        8.885188
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                      100.964915                               72.034714
# 1                      101.747321                               73.246160
# 2                      105.993915                               79.762146
# 3                      106.797600                               78.102497
# 4                      110.075144                               75.432089
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                            71.175839                              43.416587
# 1                            73.109507                              44.102154
# 2                            79.056942                              47.853944
# 3                            77.006493                              45.793013
# 4                            75.239617                              43.462628
#
#    ...  lbp-3D-k_glszm_ZonePercentage  lbp-3D-k_glszm_ZoneVariance  \
# 0  ...                       0.007881                345733.167092
# 1  ...                       0.013112                244310.331892
# 2  ...                       0.011331                222776.529605
# 3  ...                       0.012197                280222.663268
# 4  ...                       0.010859                216779.591479
#
#    lbp-3D-k_ngtdm_Busyness  lbp-3D-k_ngtdm_Coarseness  \
# 0               479.414935                   0.001538
# 1               378.001763                   0.001761
# 2               497.261162                   0.001567
# 3               406.837667                   0.001629
# 4               368.838125                   0.001912
#
#    lbp-3D-k_ngtdm_Complexity  lbp-3D-k_ngtdm_Contrast  \
# 0                   0.183049                 0.017044
# 1                   0.146021                 0.010782
# 2                   0.190309                 0.019644
# 3                   0.148247                 0.010824
# 4                   0.174701                 0.014793
#
#    lbp-3D-k_ngtdm_Strength  Sex   Age  Transition
# 0                 0.001581    0  77.1       CN-CN
# 1                 0.001813    1  83.4       CN-CN
# 2                 0.001596    1  81.3       AD-AD
# 3                 0.001677    1  79.6      CN-MCI
# 4                 0.001979    0  80.1       CN-CN
#
# [5 rows x 2014 columns]

# %% [markdown]
# ## Missing values

# %%
sns.heatmap(control.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
control.isnull().sum()
# Out:
# diagnostics_Image-original_Mean       0
# diagnostics_Image-original_Maximum    0
# diagnostics_Mask-original_VoxelNum    0
# original_shape_Elongation             0
# original_shape_Flatness               0
#                                      ..
# lbp-3D-k_ngtdm_Contrast               0
# lbp-3D-k_ngtdm_Strength               0
# Sex                                   0
# Age                                   0
# Transition                            0
# Length: 2014, dtype: int64

# %%
# Check for columns with missing values
missing_values = control.isnull().sum()

# Filter to display only columns where the number of missing values is greater than 0
missing_values = missing_values[missing_values > 0]

# Print the result
print(missing_values)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Handling Categoric Data

# %%
# Identify categorical columns (data type 'object' or 'category')
categorical_columns = control.select_dtypes(include=['object', 'category']).columns

# Iterate over each categorical column and print its unique categories
for col in categorical_columns:
    unique_values = control[col].unique()
    print(f"Column '{col}' has the following categories: {unique_values}")
# Out:
# Column 'Transition' has the following categories: ['CN-CN' 'AD-AD' 'CN-MCI' 'MCI-AD' 'MCI-MCI']

# %%
transition_count = control['Transition'].value_counts()
sns.barplot(x=transition_count.index,y=transition_count.values)
plt.show()

# %%
# Target muito unbalanced

# %% [markdown]
# ## Handeling Dates

# %%
# Identify columns with datetime64 data type
date_columns = control.select_dtypes(include=['datetime64']).columns

# Print the columns with date data type
print(f"Columns with datetime data type: {date_columns}")
# Out:
# Columns with datetime data type: Index([], dtype='object')

# %% [markdown]
# ## Handeling highly correlated features

# %%
encoded_target = pd.get_dummies(control['Transition'], prefix='category')
# Concatenate the one-hot encoded target back into your dataset
control_encoded = pd.concat([control, encoded_target], axis=1)
# Drop the original target column if needed
control_encoded.drop(columns=['Transition'],inplace=True)

# %%
fig = plt.figure(figsize=(500, 500))
control_corr = control_encoded.corr(method='pearson')
sns.heatmap(control_corr, linecolor='black', linewidths=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/PIL/ImageFile.py:547, in _save(im, fp, tile, bufsize)
#     546 try:
# --> 547     fh = fp.fileno()
#     548     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 4
#       2 control_corr = control_encoded.corr(method='pearson')
#       3 sns.heatmap(control_corr, linecolor='black', linewidths=0.5)
# ----> 4 plt.show()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/PIL/Image.py:2568, in Image.save(self, fp, format, **params)
#    2565     fp = cast(IO[bytes], fp)
#    2567 try:
# -> 2568     save_handler(self, fp, filename)
#    2569 except Exception:
#    2570     if open_fp:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1431, in _save(im, fp, filename, chunk, save_all)
#    1427     im = _write_multiple_frames(
#    1428         im, fp, chunk, mode, rawmode, default_image, append_images
#    1429     )
#    1430 if im:
# -> 1431     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1433 if info:
#    1434     for info_chunk in info.chunks:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/PIL/ImageFile.py:551, in _save(im, fp, tile, bufsize)
#     549     _encode_tile(im, fp, tile, bufsize, fh)
#     550 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 551     _encode_tile(im, fp, tile, bufsize, None, exc)
#     552 if hasattr(fp, "flush"):
#     553     fp.flush()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/PIL/ImageFile.py:570, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     567 if exc:
#     568     # compress to Python file-compatible object
#     569     while True:
# --> 570         errcode, data = encoder.encode(bufsize)[1:]
#     571         fp.write(data)
#     572         if errcode:
#
# KeyboardInterrupt:

# %%
# Demasiadas features para retirar alguma conclusão

# %%
from sklearn.feature_selection import SelectKBest, f_classif

X = control.drop(columns=['Transition'])
y = control['Transition']

k = 8 # Number of top features to select
selector = SelectKBest(f_classif, k=k)
X_new = selector.fit_transform(X, y)

# Get the boolean mask of selected features
selected_features_mask = selector.get_support()

# Get the names of the selected features
selected_features = X.columns[selected_features_mask]

# Create a new DataFrame with the selected features
controlKbest = control[selected_features.tolist() + ['Transition']]

print(f"Reduced dataset has {controlKbest.shape[1]} columns after feature selection.")
print("Selected features DataFrame:")
controlKbes = control.copy()

# %%
from sklearn.ensemble import RandomForestClassifier

X = control.drop(columns=['Transition'])  # Features
y = control['Transition']  # Target variable

# Fit a RandomForestClassifier to compute feature importances
model = RandomForestClassifier(n_estimators=1000)
model.fit(X, y)

# Get feature importances and drop low-importance features
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]  # Sort by importance

# Select top N features, for example, the top 20 features
top_n = 10
top_indices = indices[:top_n]

# Create a new DataFrame with the selected features
X_new = X.iloc[:, top_indices]

# If you want to include the target variable as well
controlKbestRandomForest = control.iloc[:, top_indices.tolist() + [control.columns.get_loc('Transition')]]

print(f"Reduced dataset has {controlKbestRandomForest.shape[1]} columns after Random Forest feature selection.")
print("Selected features DataFrame:")
controlKbestRandomForest.head()
controlKbestRandomForestK = control.copy()

# %%
encoded_target = pd.get_dummies(controlKbest['Transition'], prefix='category')
controlKbest_encoded = pd.concat([controlKbest, encoded_target], axis=1)
controlKbest_encoded.drop(columns=['Transition'],inplace=True)


fig = plt.figure(figsize = (5,5))
controlKbest_corr = controlKbest_encoded.corr( method = "pearson")
sns.heatmap(controlKbest_corr, linecolor='black', linewidths=0.5)
#plt.show()

# %%
encoded_target = pd.get_dummies(controlKbestRandomForest['Transition'], prefix='category')
controlKbest_encoded = pd.concat([controlKbestRandomForest, encoded_target], axis=1)
controlKbest_encoded.drop(columns=['Transition'],inplace=True)


fig = plt.figure(figsize = (50,50))
controlKbest_corr = controlKbest_encoded.corr( method = "pearson")
sns.heatmap(controlKbest_corr, linecolor='black', linewidths=0.5)
#plt.show()

# %%
#Remover algumas colunas
# Assuming X_new is your DataFrame with the top 80 features
# Calculate the correlation matrix

encoded_target = pd.get_dummies(controlKbestRandomForest['Transition'], prefix='category')
controlKbest_encoded = pd.concat([controlKbestRandomForest, encoded_target], axis=1)
controlKbest_encoded.drop(columns=['Transition'],inplace=True)

correlation_matrix = controlKbest_encoded.corr().abs()  # Use absolute values for correlation

# Select upper triangle of correlation matrix
upper = correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than a threshold (e.g., 0.9)
threshold = 0.9
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

# Drop the highly correlated features
X_new_reduced = X_new.drop(columns=to_drop)

# If you want to keep the target variable in the final dataset
controlKbestRandomForestReduced = pd.concat([X_new_reduced, control['Transition']], axis=1)

print(f"Reduced dataset has {controlKbestRandomForestReduced.shape[1]} columns after removing highly correlated features.")
print("Reduced DataFrame:")

encoded_target = pd.get_dummies(controlKbestRandomForestReduced['Transition'], prefix='category')
controlKbest_encoded = pd.concat([controlKbestRandomForestReduced, encoded_target], axis=1)
controlKbest_encoded.drop(columns=['Transition'],inplace=True)
ig = plt.figure(figsize = (25,25))
controlKbest_corr = controlKbest_encoded.corr( method = "pearson")
sns.heatmap(controlKbest_corr, linecolor='black', linewidths=0.5)
#plt.show()
control.

# %% [markdown]
# ### Agora Vamos modelar! ( Sem esquecer preparação de dados claro )

# %%
controlKbestRandomForestReduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 119 entries, lbp-3D-m1_glrlm_ShortRunEmphasis to Transition
# dtypes: float64(118), object(1)
# memory usage: 283.7+ KB

# %%
from sklearn.preprocessing import MinMaxScaler
# Normalizar

# Select only the float columns
float_cols = control.select_dtypes(include=['float'])

# Apply Min-Max scaling
scaler = MinMaxScaler()
scaled_float_cols = pd.DataFrame(scaler.fit_transform(float_cols), columns=float_cols.columns)

# Replace the original float columns with the scaled columns
control[float_cols.columns] = scaled_float_cols
control.head()
# Out:
#    diagnostics_Image-original_Mean  diagnostics_Image-original_Maximum  \
# 0                         0.468027                                 178
# 1                         0.281221                                 190
# 2                         0.764980                                 155
# 3                         0.651078                                 171
# 4                         0.382225                                 150
#
#    diagnostics_Mask-original_VoxelNum  original_shape_Elongation  \
# 0                                7106                   0.555087
# 1                                7779                   0.588970
# 2                                6707                   0.727218
# 3                                8281                   0.547963
# 4                                5986                   0.504096
#
#    original_shape_Flatness  original_shape_LeastAxisLength  \
# 0                 0.455539                        0.392720
# 1                 0.397306                        0.338081
# 2                 0.876712                        1.000000
# 3                 0.355153                        0.372946
# 4                 0.080905                        0.078060
#
#    original_shape_MajorAxisLength  original_shape_Maximum2DDiameterColumn  \
# 0                        0.289560                                0.310620
# 1                        0.311579                                0.359443
# 2                        0.431089                                0.622046
# 3                        0.453707                                0.555160
# 4                        0.545945                                0.447539
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                             0.254940                               0.562431
# 1                             0.335667                               0.619620
# 2                             0.583960                               0.932585
# 3                             0.498358                               0.760667
# 4                             0.424594                               0.566272
#
#    ...  lbp-3D-k_glszm_ZonePercentage  lbp-3D-k_glszm_ZoneVariance  \
# 0  ...                       0.184251                     0.633393
# 1  ...                       0.651481                     0.323882
# 2  ...                       0.492440                     0.258168
# 3  ...                       0.569706                     0.433476
# 4  ...                       0.450216                     0.239867
#
#    lbp-3D-k_ngtdm_Busyness  lbp-3D-k_ngtdm_Coarseness  \
# 0                 0.646173                   0.125643
# 1                 0.458297                   0.195642
# 2                 0.679235                   0.134842
# 3                 0.511718                   0.154368
# 4                 0.441321                   0.243251
#
#    lbp-3D-k_ngtdm_Complexity  lbp-3D-k_ngtdm_Contrast  \
# 0                   0.735632                 0.658619
# 1                   0.492265                 0.373790
# 2                   0.783349                 0.776907
# 3                   0.506896                 0.375681
# 4                   0.680762                 0.556234
#
#    lbp-3D-k_ngtdm_Strength  Sex       Age  Transition
# 0                 0.127238    0  0.610644       CN-CN
# 1                 0.198729    1  0.787115       CN-CN
# 2                 0.132002    1  0.728291       AD-AD
# 3                 0.156912    1  0.680672      CN-MCI
# 4                 0.249892    0  0.694678       CN-CN
#
# [5 rows x 2014 columns]

# %%
df = control.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 2014 entries, diagnostics_Image-original_Mean to Transition
# dtypes: float64(1994), int64(19), object(1)
# memory usage: 4.7+ MB

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt

# Assuming 'df' is already defined
X = df.drop(columns=['Transition'])  # Feature columns
y = df['Transition']  # Target column

# Step 3: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2025)

# Step 4: Initialize Random Forest Classifier
rf_model = RandomForestClassifier(
    n_estimators=500,       # Number of trees in the forest
    max_depth=1000,           # Maximum depth of the individual trees
    random_state=2024       # Seed for reproducibility
)

# Step 5: Fit the model on the training data
rf_model.fit(X_train, y_train)

# Step 6: Predict on the test data
y_pred = rf_model.predict(X_test)

# Step 7: Evaluate the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Step 8: Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Step 9: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)  # Use a blue color map for visualization
plt.title("Confusion Matrix - Random Forest")
plt.show()

# Step 10: Evaluate the model using F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' accounts for class imbalance
print(f"F1 Score (Weighted): {f1:.4f}")
# Out:
# Accuracy: 0.4416
# F1 Score (Weighted): 0.4200

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt

# Assuming 'df' is already defined
X = df.drop(columns=['Transition'])  # Feature columns
y = df['Transition']  # Target column

# Step 3: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2025)

# Step 4: Initialize Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(
    n_estimators=1000,      # Number of boosting stages (trees)
    learning_rate=0.1,     # Step size shrinkage (lower values make training more robust but slower)
    max_depth=10,           # Maximum depth of the individual regression estimators
    random_state=2024        # Seed for reproducibility
)

# Step 5: Fit the model on the training data
gb_model.fit(X_train, y_train)

# Step 6: Predict on the test data
y_pred = gb_model.predict(X_test)

# Step 7: Evaluate the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Step 8: Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Step 9: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)  # Use a blue color map for visualization
plt.title("Confusion Matrix")
plt.show()

# Step 10: Evaluate the model using F1 score
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' accounts for class imbalance
print(f"F1 Score (Weighted): {f1:.4f}")
# Out:
# Accuracy: 0.3247
# F1 Score (Weighted): 0.3272

# %%
# Modelo com Gradient Boosting + SMOTE
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Step 2: Prepare your data
X = df.drop(columns=['Transition'])  # Feature columns
y = df['Transition']  # Target column

# Step 3: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2025)

# Step 4: Apply SMOTE to the training data
smote = SMOTE(random_state=2025)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Optional: Check the class distribution after SMOTE
print(f"Original class distribution: {Counter(y_train)}")
print(f"Resampled class distribution: {Counter(y_train_resampled)}")

# Step 5: Initialize Gradient Boosting Classifier
gb_modelsmote = GradientBoostingClassifier(
    n_estimators=500,      # Number of boosting stages (trees)
    learning_rate=0.01,     # Step size shrinkage (lower values make training more robust but slower)
    max_depth=10,           # Maximum depth of the individual regression estimators
    random_state=2024        # Seed for reproducibility
)

# Step 6: Fit the model on the resampled training data
gb_modelsmote.fit(X_train_resampled, y_train_resampled)

# Step 7: Predict on the original test data (not resampled)
y_pred = gb_modelsmote.predict(X_test)

# Step 8: Evaluate the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Step 9: Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Step 10: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)  # Use a blue color map for visualization
plt.title("Confusion Matrix")
plt.show()
# Out:
# Original class distribution: Counter({'CN-CN': 70, 'MCI-AD': 54, 'MCI-MCI': 49, 'AD-AD': 46, 'CN-MCI': 9})
# Resampled class distribution: Counter({'CN-CN': 70, 'MCI-AD': 70, 'MCI-MCI': 70, 'AD-AD': 70, 'CN-MCI': 70})
# Accuracy: 0.4675

# %%
# Modelo com Gradient Boosting + SMOTE + HYP

import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from collections import Counter
import matplotlib.pyplot as plt

# Step 2: Prepare your data
X = df.drop(columns=['Transition'])  # Feature columns
y = df['Transition']  # Target column

# Step 3: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2025)

# Step 4: Apply SMOTE to the training data
smote = SMOTE(random_state=2025)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Optional: Check the class distribution after SMOTE
print(f"Original class distribution: {Counter(y_train)}")
print(f"Resampled class distribution: {Counter(y_train_resampled)}")

# Step 5: Hyperparameter tuning for Gradient Boosting Classifier
param_grid = {
    'n_estimators': [100, 200, 500,1000],  # Number of boosting stages
    'learning_rate': [0.01, 0.1, 0.2], # Step size shrinkage
    'max_depth': [3, 5, 10, 50, 100],           # Maximum depth of the individual estimators
}

gb_modelhyp = GradientBoostingClassifier(random_state=2025)

grid_search = GridSearchCV(estimator=gb_modelhyp, param_grid=param_grid, 
                           scoring='accuracy', cv=3, verbose=2, n_jobs=-1)

# Step 6: Fit the model on the resampled training data
grid_search.fit(X_train_resampled, y_train_resampled)

# Best parameters and estimator
best_model_gb = grid_search.best_estimator_
print("Best parameters found: ", grid_search.best_params_)

# Step 7: Predict on the original test data (not resampled)
y_pred = best_model_gb.predict(X_test)

# Step 8: Evaluate the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Step 9: Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Step 10: Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Gradient Boosting")
plt.show()
# Out:
# Original class distribution: Counter({'CN-CN': 70, 'MCI-AD': 54, 'MCI-MCI': 49, 'AD-AD': 46, 'CN-MCI': 9})
# Resampled class distribution: Counter({'CN-CN': 70, 'MCI-AD': 70, 'MCI-MCI': 70, 'AD-AD': 70, 'CN-MCI': 70})
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Accuracy: 0.4545

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import xgboost as xgb

# Step 1: Prepare your data
X = df.drop(columns=['Transition'])  # Feature columns
y = df['Transition']  # Target column

# Step 2: Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Step 3: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.25, random_state=2025)

# Step 4: Apply SMOTE to the training data
smote = SMOTE(random_state=2025)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Step 11: Hyperparameter tuning for XGBoost Classifier
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=2025)

param_grid_xgb = {
    'n_estimators': [1000],  # Number of boosting stages
    'learning_rate': [0.01], # Step size shrinkage
    'max_depth': [20],       # Maximum depth of the individual estimators
    'subsample': [0.6, 0.8, 1.0],  # Fraction of samples to be used for fitting the individual base learners
}

grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb, 
                               scoring='accuracy', cv=3, verbose=2, n_jobs=-1)

# Step 12: Fit the model on the resampled training data
grid_search_xgb.fit(X_train_resampled, y_train_resampled)

# Best parameters and estimator
best_model_xgb = grid_search_xgb.best_estimator_
print("Best parameters found for XGBoost: ", grid_search_xgb.best_params_)

# Step 13: Predict on the original test data (not resampled)
y_pred_xgb = best_model_xgb.predict(X_test)

# Step 14: Evaluate the model using accuracy
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f"Accuracy (XGBoost): {accuracy_xgb:.4f}")

# Step 15: Compute the confusion matrix
cm_xgb = confusion_matrix(y_test, y_pred_xgb)

# Step 16: Display the confusion matrix
disp_xgb = ConfusionMatrixDisplay(confusion_matrix=cm_xgb)
disp_xgb.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - XGBoost")
plt.show()

# Step 17: Evaluate the model using F1 score
f1_xgb = f1_score(y_test, y_pred_xgb, average='weighted')  # 'weighted' handles class imbalance
print(f"F1 Score (XGBoost, Weighted): {f1_xgb:.4f}")
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.6; total time= 9.0min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.8; total time= 9.6min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.8; total time= 9.6min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.6; total time= 9.7min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=1.0; total time=10.0min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=1.0; total time=10.0min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.8; total time=10.1min
# Best parameters found for XGBoost:  {'learning_rate': 0.01, 'max_depth': 20, 'n_estimators': 1000, 'subsample': 0.8}
# Accuracy (XGBoost): 0.4026
# F1 Score (XGBoost, Weighted): 0.3890
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=0.6; total time= 8.9min
# [CV] END learning_rate=0.01, max_depth=20, n_estimators=1000, subsample=1.0; total time= 4.4min

# %%
# Load the test dataset
test_data = pd.read_csv("sbsppdaa24/test_radiomics_hipocamp.csv")

# Apply the same preprocessing steps as we did for training data
# 1. Drop unnecessary columns
test_data.drop(columns=["Mask", "ID", "Image"], inplace=True)

# 2. Drop constant columns (use the same columns we dropped in training)
columns_to_drop = [col for col in test_data.columns if test_data[col].nunique() == 1]
test_data.drop(columns=columns_to_drop, inplace=True)

# 3. Drop Hash columns
hash_columns = [col for col in test_data.columns if 'Hash' in col]
test_data.drop(columns=hash_columns, inplace=True)

# 4. Keep only the features we used in training (from controlKbestRandomForestReduced)
test_features = test_data[X.columns].copy()

# 5. Apply the same scaling
scaler = MinMaxScaler()
float_cols = test_features.select_dtypes(include=['float'])
scaled_float_cols = pd.DataFrame(
    scaler.fit_transform(float_cols), 
    columns=float_cols.columns
)

# Use .loc to avoid the SettingWithCopyWarning
test_features.loc[:, float_cols.columns] = scaled_float_cols


predictions_random_forest_no_smote = rf_model.predict(test_features)

# Make predictions using both models
# Model without SMOTE
predictions_no_smote = gb_model.predict(test_features)

"""
# Model with SMOTE
predictions_with_smote = gb_modelsmote.predict(test_features)  # Using the SMOTE-trained model

# Model with SMOTE
predictions_with_smote_with_hyp = best_model_gb.predict(test_features)  # Using the SMOTE-trained model
"""
predictions_with_smote_with_hyp_xgb = best_model_xgb.predict(test_features)  # Using the SMOTE-trained model
predictions_with_smote_with_hyp_xgb_labels = label_encoder.inverse_transform(predictions_with_smote_with_hyp_xgb)


results_random_forest_no_smote = pd.DataFrame({
    'RowId': range(1, len(predictions_random_forest_no_smote) + 1),
    'Result': predictions_random_forest_no_smote
})

# Create DataFrames with predictions, starting from ID 1
results_no_smote = pd.DataFrame({
    'RowId': range(1, len(predictions_no_smote) + 1),
    'Result': predictions_no_smote
})
"""
results_with_smote = pd.DataFrame({
    'RowId': range(1, len(predictions_with_smote) + 1),
    'Result': predictions_with_smote
})

predictions_with_smote_with_hyp = pd.DataFrame({
    'RowId': range(1, len(predictions_with_smote) + 1),
    'Result':predictions_with_smote_with_hyp
})
"""

predictions_with_smote_with_hyp_xgb_labels = pd.DataFrame({
    'RowId': range(1, len(predictions_with_smote_with_hyp_xgb_labels) + 1),
    'Result': predictions_with_smote_with_hyp_xgb_labels
})


# Save predictions to CSV files
results_no_smote.to_csv('predictions_no_smote.csv', index=False)
results_random_forest_no_smote.to_csv('predictions_random_forest_no_smote.csv', index=False)
"""
results_with_smote.to_csv('predictions_with_smote.csv', index=False)
predictions_with_smote_with_hyp.to_csv('predictions_with_smote_with_hyp.csv',index=False)
"""
predictions_with_smote_with_hyp_xgb_labels.to_csv('predictions_with_smote_with_hyp_xgb.csv',index=False)
