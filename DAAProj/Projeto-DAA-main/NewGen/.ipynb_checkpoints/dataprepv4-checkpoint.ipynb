# %%
import os
import random
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
def set_seed(seed: int):
    random.seed(seed) # Python
    np.random.seed(seed)  # Numpy, é o gerador utilizado pelo sklearn
    os.environ["PYTHONHASHSEED"] = str(seed)  # sistema operativo

set_seed(25)

# %%
# Load datasets
radi = pd.read_csv("../sbsppdaa24/train_radiomics_hipocamp.csv")
radi_test = pd.read_csv("../sbsppdaa24/test_radiomics_hipocamp.csv")

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Drop unique identifier columns
radi.drop(columns=["Mask", "ID", "Image"], inplace=True)
print("Dropped unique identifier columns from training dataset.")

# Drop columns where all entries are the same
same_value_cols_train = [col for col in radi.columns if radi[col].nunique() == 1]
radi.drop(columns=same_value_cols_train, inplace=True)
print(f"Dropped {len(same_value_cols_train)} constant-value columns from training dataset.")

# Separate target feature (Transition) from the dataset
target = radi['Transition']
radi.drop(columns=['Transition'], inplace=True)

# Identify non-numeric columns
non_numeric_cols = radi.select_dtypes(include=['object', 'category']).columns
print(f"Non-numeric columns identified: {list(non_numeric_cols)}")

# Drop or encode non-numeric columns
radi.drop(columns=non_numeric_cols, inplace=True)

# Apply MinMax scaling to numeric columns
numeric_cols = radi.select_dtypes(include=['float', 'int']).columns
scaler = MinMaxScaler()
radi[numeric_cols] = scaler.fit_transform(radi[numeric_cols])
print("Scaled numeric columns using MinMaxScaler.")

# PCA transformation
pca = PCA(n_components=0.95)
radi_pca = pca.fit_transform(radi)

# Generate component names based on the most contributing original features
original_feature_names = radi.columns
components_with_original_features = [
    "+".join(original_feature_names[np.argsort(-np.abs(pca.components_[i]))[:3]])
    for i in range(radi_pca.shape[1])
]

# Convert PCA result to DataFrame using the generated names
radi_pca_df = pd.DataFrame(radi_pca, columns=components_with_original_features)

radi_pca_df = pd.concat([radi_pca_df, target.reset_index(drop=True)], axis=1)
# Check final data structure
print("Final dataset structure:")
radi_pca_df.info()

# train_full_prep4
radi_pca_df.to_csv("train_full_prep4.csv",index=False)


# Drop unique identifier columns
radi_test.drop(columns=["Mask", "ID", "Image"], inplace=True, errors='ignore')

# Drop the same constant-value columns as in the training data
radi_test.drop(columns=same_value_cols_train, inplace=True, errors='ignore')

# Drop the same non-numeric columns as in the training data
radi_test.drop(columns=non_numeric_cols, inplace=True, errors='ignore')

# Apply MinMax scaling to numeric columns in the test data using the previously fitted scaler
radi_test[numeric_cols] = scaler.transform(radi_test[numeric_cols])  # Use the same scaler as training

# Apply PCA transformation to the test data using the previously fitted PCA
radi_test_pca = pca.transform(radi_test)

# Convert PCA-transformed test data to DataFrame using the same column names as for the training data
radi_test_pca_df = pd.DataFrame(radi_test_pca, columns=components_with_original_features)

# Check final test dataset structure
print("Final test dataset structure:")
radi_test_pca_df.info()

# Save the processed test dataset
radi_test_pca_df.to_csv("test_processed_prep4.csv", index=False)
# Out:
# Dropped unique identifier columns from training dataset.
# Dropped 159 constant-value columns from training dataset.
# Non-numeric columns identified: ['diagnostics_Image-original_Hash', 'diagnostics_Mask-original_Hash', 'diagnostics_Mask-original_BoundingBox', 'diagnostics_Mask-original_CenterOfMassIndex', 'diagnostics_Mask-original_CenterOfMass']
# Scaled numeric columns using MinMaxScaler.
# Final dataset structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 87 columns):
#  #   Column                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                           --------------  -----
#  0   lbp-3D-m1_firstorder_Median+log-sigma-2-0-mm-3D_glcm_ClusterShade+log-sigma-2-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis                                        305 non-null    float64
#  1   exponential_ngtdm_Coarseness+exponential_glszm_LowGrayLevelZoneEmphasis+exponential_glcm_MCC                                                                     305 non-null    float64
#  2   exponential_ngtdm_Coarseness+exponential_glcm_MCC+exponential_glcm_Correlation                                                                                   305 non-null    float64
#  3   wavelet-HHL_ngtdm_Contrast+wavelet-HHL_gldm_LargeDependenceLowGrayLevelEmphasis+wavelet-HHL_gldm_LowGrayLevelEmphasis                                            305 non-null    float64
#  4   log-sigma-4-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-4-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis  305 non-null    float64
#  5   exponential_ngtdm_Coarseness+log-sigma-4-0-mm-3D_glcm_Autocorrelation+log-sigma-3-0-mm-3D_glcm_Autocorrelation                                                   305 non-null    float64
#  6   log-sigma-1-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis      305 non-null    float64
#  7   log-sigma-2-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis      305 non-null    float64
#  8   log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+wavelet-LHH_glrlm_HighGrayLevelRunEmphasis+log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis             305 non-null    float64
#  9   logarithm_glcm_JointEnergy+logarithm_firstorder_Uniformity+logarithm_glcm_Idn                                                                                    305 non-null    float64
#  10  lbp-3D-m1_firstorder_Median+squareroot_ngtdm_Strength+log-sigma-2-0-mm-3D_glcm_MaximumProbability                                                                305 non-null    float64
#  11  wavelet-LHH_glrlm_HighGrayLevelRunEmphasis+wavelet-LHH_glcm_Autocorrelation+wavelet-LHH_glrlm_LowGrayLevelRunEmphasis                                            305 non-null    float64
#  12  log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-4-0-mm-3D_glrlm_LowGrayLevelRunEmphasis      305 non-null    float64
#  13  wavelet-LLH_glrlm_HighGrayLevelRunEmphasis+wavelet-LLH_gldm_HighGrayLevelEmphasis+wavelet-LLH_glcm_Autocorrelation                                               305 non-null    float64
#  14  wavelet-LLH_glrlm_HighGrayLevelRunEmphasis+wavelet-LLH_gldm_HighGrayLevelEmphasis+wavelet-LLH_glcm_Autocorrelation                                               305 non-null    float64
#  15  exponential_glszm_GrayLevelNonUniformityNormalized+exponential_glszm_GrayLevelVariance+exponential_glcm_MCC                                                      305 non-null    float64
#  16  log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-5-0-mm-3D_glrlm_LowGrayLevelRunEmphasis      305 non-null    float64
#  17  log-sigma-5-0-mm-3D_glcm_DifferenceVariance+log-sigma-5-0-mm-3D_glcm_DifferenceEntropy+log-sigma-5-0-mm-3D_glcm_Idm                                              305 non-null    float64
#  18  Sex+log-sigma-3-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-3-0-mm-3D_glrlm_LowGrayLevelRunEmphasis                                                         305 non-null    float64
#  19  log-sigma-5-0-mm-3D_gldm_HighGrayLevelEmphasis+log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_glrlm_LowGrayLevelRunEmphasis              305 non-null    float64
#  20  lbp-2D_firstorder_90Percentile+log-sigma-3-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-3-0-mm-3D_glrlm_HighGrayLevelRunEmphasis                              305 non-null    float64
#  21  log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_gldm_HighGrayLevelEmphasis+log-sigma-5-0-mm-3D_glcm_Autocorrelation                       305 non-null    float64
#  22  wavelet-LHL_glcm_SumAverage+wavelet-LHL_glcm_JointAverage+wavelet-LHL_glcm_Autocorrelation                                                                       305 non-null    float64
#  23  Sex+exponential_ngtdm_Coarseness+exponential_glszm_GrayLevelVariance                                                                                             305 non-null    float64
#  24  exponential_ngtdm_Coarseness+exponential_glcm_MCC+log-sigma-2-0-mm-3D_glcm_Imc2                                                                                  305 non-null    float64
#  25  original_glszm_LowGrayLevelZoneEmphasis+original_glrlm_LowGrayLevelRunEmphasis+wavelet-HLL_ngtdm_Complexity                                                      305 non-null    float64
#  26  wavelet-LLH_glcm_Idmn+gradient_glcm_MCC+wavelet-LLH_ngtdm_Complexity                                                                                             305 non-null    float64
#  27  lbp-2D_firstorder_90Percentile+Sex+lbp-2D_firstorder_RobustMeanAbsoluteDeviation                                                                                 305 non-null    float64
#  28  wavelet-LLH_glcm_Idmn+wavelet-LLH_glcm_Imc1+wavelet-LLH_glcm_Idn                                                                                                 305 non-null    float64
#  29  Sex+wavelet-LLH_glcm_Idmn+wavelet-LLH_firstorder_Maximum                                                                                                         305 non-null    float64
#  30  Sex+lbp-3D-m1_firstorder_Median+squareroot_glrlm_ShortRunLowGrayLevelEmphasis                                                                                    305 non-null    float64
#  31  log-sigma-2-0-mm-3D_glcm_Imc1+log-sigma-2-0-mm-3D_glcm_Correlation+log-sigma-2-0-mm-3D_glcm_Imc2                                                                 305 non-null    float64
#  32  square_glcm_ClusterShade+lbp-2D_firstorder_InterquartileRange+log-sigma-1-0-mm-3D_gldm_DependenceVariance                                                        305 non-null    float64
#  33  lbp-2D_firstorder_90Percentile+lbp-2D_firstorder_RobustMeanAbsoluteDeviation+wavelet-HLL_glszm_SmallAreaLowGrayLevelEmphasis                                     305 non-null    float64
#  34  wavelet-HHH_glszm_SmallAreaLowGrayLevelEmphasis+wavelet-HLH_ngtdm_Contrast+wavelet-HLH_glcm_Idmn                                                                 305 non-null    float64
#  35  lbp-2D_firstorder_90Percentile+Sex+wavelet-LHH_glszm_SmallAreaEmphasis                                                                                           305 non-null    float64
#  36  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+Sex                                                                                                      305 non-null    float64
#  37  gradient_firstorder_Minimum+lbp-3D-m2_firstorder_Maximum+lbp-3D-m2_firstorder_Range                                                                              305 non-null    float64
#  38  wavelet-LHH_ngtdm_Contrast+wavelet-LHH_glcm_Idmn+wavelet-LHH_glcm_Idn                                                                                            305 non-null    float64
#  39  lbp-3D-m1_firstorder_Median+Sex+lbp-2D_firstorder_90Percentile                                                                                                   305 non-null    float64
#  40  Sex+gradient_firstorder_Minimum+log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis                                                                                      305 non-null    float64
#  41  Sex+lbp-2D_firstorder_90Percentile+lbp-2D_firstorder_RobustMeanAbsoluteDeviation                                                                                 305 non-null    float64
#  42  gradient_firstorder_Minimum+log-sigma-1-0-mm-3D_glcm_Imc2+wavelet-LHH_glcm_MaximumProbability                                                                    305 non-null    float64
#  43  lbp-3D-m2_firstorder_Maximum+lbp-3D-m2_firstorder_Range+lbp-3D-k_glszm_SizeZoneNonUniformityNormalized                                                           305 non-null    float64
#  44  Sex+wavelet-LHH_glszm_SmallAreaEmphasis+wavelet-LHH_glszm_SizeZoneNonUniformityNormalized                                                                        305 non-null    float64
#  45  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+log-sigma-5-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis                                                  305 non-null    float64
#  46  Sex+lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum                                                                                                      305 non-null    float64
#  47  gradient_firstorder_Minimum+wavelet-LHH_glszm_SmallAreaEmphasis+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                                        305 non-null    float64
#  48  lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized+wavelet-LLH_glszm_SizeZoneNonUniformity                                         305 non-null    float64
#  49  wavelet-HHL_glszm_SizeZoneNonUniformityNormalized+wavelet-HHL_glszm_SizeZoneNonUniformity+wavelet-HHL_glszm_SmallAreaEmphasis                                    305 non-null    float64
#  50  logarithm_glszm_GrayLevelNonUniformity+logarithm_gldm_DependenceVariance+logarithm_glszm_SizeZoneNonUniformityNormalized                                         305 non-null    float64
#  51  log-sigma-4-0-mm-3D_glszm_SmallAreaEmphasis+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity            305 non-null    float64
#  52  lbp-3D-m1_firstorder_Median+square_glszm_SmallAreaEmphasis+square_glszm_SizeZoneNonUniformityNormalized                                                          305 non-null    float64
#  53  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+wavelet-HHL_glszm_SmallAreaEmphasis                                                                      305 non-null    float64
#  54  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity                                                          305 non-null    float64
#  55  gradient_glszm_SizeZoneNonUniformity+gradient_glszm_SmallAreaEmphasis+lbp-2D_firstorder_InterquartileRange                                                       305 non-null    float64
#  56  lbp-2D_firstorder_90Percentile+log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+log-sigma-2-0-mm-3D_glszm_SmallAreaEmphasis                             305 non-null    float64
#  57  gradient_firstorder_Minimum+lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized                                                     305 non-null    float64
#  58  gradient_firstorder_Minimum+Sex+gradient_glszm_ZoneEntropy                                                                                                       305 non-null    float64
#  59  logarithm_glszm_SizeZoneNonUniformity+logarithm_glszm_GrayLevelNonUniformity+wavelet-HHH_gldm_GrayLevelVariance                                                  305 non-null    float64
#  60  log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformity+log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis+wavelet-HHL_glcm_SumEntropy                                          305 non-null    float64
#  61  log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis+square_glszm_SmallAreaEmphasis+log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                             305 non-null    float64
#  62  wavelet-HLH_glszm_SizeZoneNonUniformityNormalized+wavelet-HLH_glszm_ZoneEntropy+wavelet-HLH_glszm_SmallAreaEmphasis                                              305 non-null    float64
#  63  wavelet-HLH_glszm_SizeZoneNonUniformityNormalized+wavelet-HLH_glszm_SmallAreaEmphasis+wavelet-HLH_glszm_SizeZoneNonUniformity                                    305 non-null    float64
#  64  gradient_firstorder_Minimum+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+exponential_ngtdm_Strength                                                 305 non-null    float64
#  65  gradient_firstorder_Minimum+lbp-3D-m1_firstorder_Median+log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                                                305 non-null    float64
#  66  wavelet-HHH_glszm_GrayLevelVariance+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+wavelet-HHH_glszm_LowGrayLevelZoneEmphasis                                305 non-null    float64
#  67  lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SmallAreaHighGrayLevelEmphasis+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized                                305 non-null    float64
#  68  wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+wavelet-HHH_glszm_GrayLevelVariance+log-sigma-4-0-mm-3D_glszm_ZoneEntropy                                     305 non-null    float64
#  69  Sex+lbp-3D-m1_firstorder_Median+original_glszm_SizeZoneNonUniformityNormalized                                                                                   305 non-null    float64
#  70  lbp-3D-m1_firstorder_Median+squareroot_glszm_SmallAreaEmphasis+squareroot_glszm_SizeZoneNonUniformityNormalized                                                  305 non-null    float64
#  71  wavelet-HHH_glszm_GrayLevelVariance+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity                           305 non-null    float64
#  72  wavelet-HHL_glszm_SizeZoneNonUniformityNormalized+wavelet-LLL_glszm_SmallAreaEmphasis+wavelet-LLL_glszm_SizeZoneNonUniformityNormalized                          305 non-null    float64
#  73  wavelet-HHH_glszm_LowGrayLevelZoneEmphasis+wavelet-HHH_glszm_HighGrayLevelZoneEmphasis+lbp-2D_firstorder_InterquartileRange                                      305 non-null    float64
#  74  log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis+wavelet-LLH_glszm_GrayLevelNonUniformityNormalized+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformity                   305 non-null    float64
#  75  wavelet-HHH_firstorder_Uniformity+wavelet-HHH_gldm_GrayLevelVariance+wavelet-HHH_firstorder_Entropy                                                              305 non-null    float64
#  76  square_glszm_SmallAreaLowGrayLevelEmphasis+lbp-3D-m1_firstorder_Median+square_glszm_HighGrayLevelZoneEmphasis                                                    305 non-null    float64
#  77  lbp-2D_firstorder_InterquartileRange+lbp-3D-m1_firstorder_Median+gradient_glcm_MCC                                                                               305 non-null    float64
#  78  log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis            305 non-null    float64
#  79  log-sigma-1-0-mm-3D_glcm_ClusterProminence+log-sigma-1-0-mm-3D_firstorder_Maximum+log-sigma-1-0-mm-3D_firstorder_Range                                           305 non-null    float64
#  80  lbp-2D_firstorder_90Percentile+logarithm_glszm_SizeZoneNonUniformityNormalized+logarithm_glszm_SmallAreaEmphasis                                                 305 non-null    float64
#  81  lbp-3D-m1_firstorder_Median+wavelet-LLH_glcm_ClusterShade+gradient_firstorder_Minimum                                                                            305 non-null    float64
#  82  squareroot_glszm_SmallAreaEmphasis+squareroot_glszm_SizeZoneNonUniformityNormalized+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized                           305 non-null    float64
#  83  Sex+lbp-3D-m1_firstorder_Median+wavelet-LHH_glszm_SmallAreaEmphasis                                                                                              305 non-null    float64
#  84  wavelet-HLH_glszm_LowGrayLevelZoneEmphasis+wavelet-HLH_glszm_SmallAreaHighGrayLevelEmphasis+wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis                      305 non-null    float64
#  85  wavelet-HLH_firstorder_Minimum+lbp-2D_firstorder_90Percentile+lbp-3D-m1_firstorder_Median                                                                        305 non-null    float64
#  86  wavelet-LLL_glszm_SmallAreaEmphasis+wavelet-LLL_glszm_SizeZoneNonUniformityNormalized+lbp-3D-m1_firstorder_Skewness                                              305 non-null    float64
# dtypes: float64(87)
# memory usage: 207.4 KB
# Final test dataset structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 87 columns):
#  #   Column                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                           --------------  -----
#  0   lbp-3D-m1_firstorder_Median+log-sigma-2-0-mm-3D_glcm_ClusterShade+log-sigma-2-0-mm-3D_glrlm_ShortRunHighGrayLevelEmphasis                                        100 non-null    float64
#  1   exponential_ngtdm_Coarseness+exponential_glszm_LowGrayLevelZoneEmphasis+exponential_glcm_MCC                                                                     100 non-null    float64
#  2   exponential_ngtdm_Coarseness+exponential_glcm_MCC+exponential_glcm_Correlation                                                                                   100 non-null    float64
#  3   wavelet-HHL_ngtdm_Contrast+wavelet-HHL_gldm_LargeDependenceLowGrayLevelEmphasis+wavelet-HHL_gldm_LowGrayLevelEmphasis                                            100 non-null    float64
#  4   log-sigma-4-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-4-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis  100 non-null    float64
#  5   exponential_ngtdm_Coarseness+log-sigma-4-0-mm-3D_glcm_Autocorrelation+log-sigma-3-0-mm-3D_glcm_Autocorrelation                                                   100 non-null    float64
#  6   log-sigma-1-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis      100 non-null    float64
#  7   log-sigma-2-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis      100 non-null    float64
#  8   log-sigma-1-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+wavelet-LHH_glrlm_HighGrayLevelRunEmphasis+log-sigma-1-0-mm-3D_glrlm_HighGrayLevelRunEmphasis             100 non-null    float64
#  9   logarithm_glcm_JointEnergy+logarithm_firstorder_Uniformity+logarithm_glcm_Idn                                                                                    100 non-null    float64
#  10  lbp-3D-m1_firstorder_Median+squareroot_ngtdm_Strength+log-sigma-2-0-mm-3D_glcm_MaximumProbability                                                                100 non-null    float64
#  11  wavelet-LHH_glrlm_HighGrayLevelRunEmphasis+wavelet-LHH_glcm_Autocorrelation+wavelet-LHH_glrlm_LowGrayLevelRunEmphasis                                            100 non-null    float64
#  12  log-sigma-2-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-2-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-4-0-mm-3D_glrlm_LowGrayLevelRunEmphasis      100 non-null    float64
#  13  wavelet-LLH_glrlm_HighGrayLevelRunEmphasis+wavelet-LLH_gldm_HighGrayLevelEmphasis+wavelet-LLH_glcm_Autocorrelation                                               100 non-null    float64
#  14  wavelet-LLH_glrlm_HighGrayLevelRunEmphasis+wavelet-LLH_gldm_HighGrayLevelEmphasis+wavelet-LLH_glcm_Autocorrelation                                               100 non-null    float64
#  15  exponential_glszm_GrayLevelNonUniformityNormalized+exponential_glszm_GrayLevelVariance+exponential_glcm_MCC                                                      100 non-null    float64
#  16  log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_glrlm_ShortRunLowGrayLevelEmphasis+log-sigma-5-0-mm-3D_glrlm_LowGrayLevelRunEmphasis      100 non-null    float64
#  17  log-sigma-5-0-mm-3D_glcm_DifferenceVariance+log-sigma-5-0-mm-3D_glcm_DifferenceEntropy+log-sigma-5-0-mm-3D_glcm_Idm                                              100 non-null    float64
#  18  Sex+log-sigma-3-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-3-0-mm-3D_glrlm_LowGrayLevelRunEmphasis                                                         100 non-null    float64
#  19  log-sigma-5-0-mm-3D_gldm_HighGrayLevelEmphasis+log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_glrlm_LowGrayLevelRunEmphasis              100 non-null    float64
#  20  lbp-2D_firstorder_90Percentile+log-sigma-3-0-mm-3D_glrlm_LowGrayLevelRunEmphasis+log-sigma-3-0-mm-3D_glrlm_HighGrayLevelRunEmphasis                              100 non-null    float64
#  21  log-sigma-5-0-mm-3D_glrlm_HighGrayLevelRunEmphasis+log-sigma-5-0-mm-3D_gldm_HighGrayLevelEmphasis+log-sigma-5-0-mm-3D_glcm_Autocorrelation                       100 non-null    float64
#  22  wavelet-LHL_glcm_SumAverage+wavelet-LHL_glcm_JointAverage+wavelet-LHL_glcm_Autocorrelation                                                                       100 non-null    float64
#  23  Sex+exponential_ngtdm_Coarseness+exponential_glszm_GrayLevelVariance                                                                                             100 non-null    float64
#  24  exponential_ngtdm_Coarseness+exponential_glcm_MCC+log-sigma-2-0-mm-3D_glcm_Imc2                                                                                  100 non-null    float64
#  25  original_glszm_LowGrayLevelZoneEmphasis+original_glrlm_LowGrayLevelRunEmphasis+wavelet-HLL_ngtdm_Complexity                                                      100 non-null    float64
#  26  wavelet-LLH_glcm_Idmn+gradient_glcm_MCC+wavelet-LLH_ngtdm_Complexity                                                                                             100 non-null    float64
#  27  lbp-2D_firstorder_90Percentile+Sex+lbp-2D_firstorder_RobustMeanAbsoluteDeviation                                                                                 100 non-null    float64
#  28  wavelet-LLH_glcm_Idmn+wavelet-LLH_glcm_Imc1+wavelet-LLH_glcm_Idn                                                                                                 100 non-null    float64
#  29  Sex+wavelet-LLH_glcm_Idmn+wavelet-LLH_firstorder_Maximum                                                                                                         100 non-null    float64
#  30  Sex+lbp-3D-m1_firstorder_Median+squareroot_glrlm_ShortRunLowGrayLevelEmphasis                                                                                    100 non-null    float64
#  31  log-sigma-2-0-mm-3D_glcm_Imc1+log-sigma-2-0-mm-3D_glcm_Correlation+log-sigma-2-0-mm-3D_glcm_Imc2                                                                 100 non-null    float64
#  32  square_glcm_ClusterShade+lbp-2D_firstorder_InterquartileRange+log-sigma-1-0-mm-3D_gldm_DependenceVariance                                                        100 non-null    float64
#  33  lbp-2D_firstorder_90Percentile+lbp-2D_firstorder_RobustMeanAbsoluteDeviation+wavelet-HLL_glszm_SmallAreaLowGrayLevelEmphasis                                     100 non-null    float64
#  34  wavelet-HHH_glszm_SmallAreaLowGrayLevelEmphasis+wavelet-HLH_ngtdm_Contrast+wavelet-HLH_glcm_Idmn                                                                 100 non-null    float64
#  35  lbp-2D_firstorder_90Percentile+Sex+wavelet-LHH_glszm_SmallAreaEmphasis                                                                                           100 non-null    float64
#  36  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+Sex                                                                                                      100 non-null    float64
#  37  gradient_firstorder_Minimum+lbp-3D-m2_firstorder_Maximum+lbp-3D-m2_firstorder_Range                                                                              100 non-null    float64
#  38  wavelet-LHH_ngtdm_Contrast+wavelet-LHH_glcm_Idmn+wavelet-LHH_glcm_Idn                                                                                            100 non-null    float64
#  39  lbp-3D-m1_firstorder_Median+Sex+lbp-2D_firstorder_90Percentile                                                                                                   100 non-null    float64
#  40  Sex+gradient_firstorder_Minimum+log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis                                                                                      100 non-null    float64
#  41  Sex+lbp-2D_firstorder_90Percentile+lbp-2D_firstorder_RobustMeanAbsoluteDeviation                                                                                 100 non-null    float64
#  42  gradient_firstorder_Minimum+log-sigma-1-0-mm-3D_glcm_Imc2+wavelet-LHH_glcm_MaximumProbability                                                                    100 non-null    float64
#  43  lbp-3D-m2_firstorder_Maximum+lbp-3D-m2_firstorder_Range+lbp-3D-k_glszm_SizeZoneNonUniformityNormalized                                                           100 non-null    float64
#  44  Sex+wavelet-LHH_glszm_SmallAreaEmphasis+wavelet-LHH_glszm_SizeZoneNonUniformityNormalized                                                                        100 non-null    float64
#  45  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+log-sigma-5-0-mm-3D_glszm_SmallAreaLowGrayLevelEmphasis                                                  100 non-null    float64
#  46  Sex+lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum                                                                                                      100 non-null    float64
#  47  gradient_firstorder_Minimum+wavelet-LHH_glszm_SmallAreaEmphasis+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                                        100 non-null    float64
#  48  lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized+wavelet-LLH_glszm_SizeZoneNonUniformity                                         100 non-null    float64
#  49  wavelet-HHL_glszm_SizeZoneNonUniformityNormalized+wavelet-HHL_glszm_SizeZoneNonUniformity+wavelet-HHL_glszm_SmallAreaEmphasis                                    100 non-null    float64
#  50  logarithm_glszm_GrayLevelNonUniformity+logarithm_gldm_DependenceVariance+logarithm_glszm_SizeZoneNonUniformityNormalized                                         100 non-null    float64
#  51  log-sigma-4-0-mm-3D_glszm_SmallAreaEmphasis+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity            100 non-null    float64
#  52  lbp-3D-m1_firstorder_Median+square_glszm_SmallAreaEmphasis+square_glszm_SizeZoneNonUniformityNormalized                                                          100 non-null    float64
#  53  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+wavelet-HHL_glszm_SmallAreaEmphasis                                                                      100 non-null    float64
#  54  lbp-3D-m2_firstorder_Range+lbp-3D-m2_firstorder_Maximum+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity                                                          100 non-null    float64
#  55  gradient_glszm_SizeZoneNonUniformity+gradient_glszm_SmallAreaEmphasis+lbp-2D_firstorder_InterquartileRange                                                       100 non-null    float64
#  56  lbp-2D_firstorder_90Percentile+log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+log-sigma-2-0-mm-3D_glszm_SmallAreaEmphasis                             100 non-null    float64
#  57  gradient_firstorder_Minimum+lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized                                                     100 non-null    float64
#  58  gradient_firstorder_Minimum+Sex+gradient_glszm_ZoneEntropy                                                                                                       100 non-null    float64
#  59  logarithm_glszm_SizeZoneNonUniformity+logarithm_glszm_GrayLevelNonUniformity+wavelet-HHH_gldm_GrayLevelVariance                                                  100 non-null    float64
#  60  log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformity+log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis+wavelet-HHL_glcm_SumEntropy                                          100 non-null    float64
#  61  log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis+square_glszm_SmallAreaEmphasis+log-sigma-3-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                             100 non-null    float64
#  62  wavelet-HLH_glszm_SizeZoneNonUniformityNormalized+wavelet-HLH_glszm_ZoneEntropy+wavelet-HLH_glszm_SmallAreaEmphasis                                              100 non-null    float64
#  63  wavelet-HLH_glszm_SizeZoneNonUniformityNormalized+wavelet-HLH_glszm_SmallAreaEmphasis+wavelet-HLH_glszm_SizeZoneNonUniformity                                    100 non-null    float64
#  64  gradient_firstorder_Minimum+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+exponential_ngtdm_Strength                                                 100 non-null    float64
#  65  gradient_firstorder_Minimum+lbp-3D-m1_firstorder_Median+log-sigma-2-0-mm-3D_glszm_SizeZoneNonUniformityNormalized                                                100 non-null    float64
#  66  wavelet-HHH_glszm_GrayLevelVariance+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+wavelet-HHH_glszm_LowGrayLevelZoneEmphasis                                100 non-null    float64
#  67  lbp-2D_firstorder_90Percentile+wavelet-HHH_glszm_SmallAreaHighGrayLevelEmphasis+wavelet-HHH_glszm_SizeZoneNonUniformityNormalized                                100 non-null    float64
#  68  wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+wavelet-HHH_glszm_GrayLevelVariance+log-sigma-4-0-mm-3D_glszm_ZoneEntropy                                     100 non-null    float64
#  69  Sex+lbp-3D-m1_firstorder_Median+original_glszm_SizeZoneNonUniformityNormalized                                                                                   100 non-null    float64
#  70  lbp-3D-m1_firstorder_Median+squareroot_glszm_SmallAreaEmphasis+squareroot_glszm_SizeZoneNonUniformityNormalized                                                  100 non-null    float64
#  71  wavelet-HHH_glszm_GrayLevelVariance+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized+log-sigma-4-0-mm-3D_glszm_SizeZoneNonUniformity                           100 non-null    float64
#  72  wavelet-HHL_glszm_SizeZoneNonUniformityNormalized+wavelet-LLL_glszm_SmallAreaEmphasis+wavelet-LLL_glszm_SizeZoneNonUniformityNormalized                          100 non-null    float64
#  73  wavelet-HHH_glszm_LowGrayLevelZoneEmphasis+wavelet-HHH_glszm_HighGrayLevelZoneEmphasis+lbp-2D_firstorder_InterquartileRange                                      100 non-null    float64
#  74  log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis+wavelet-LLH_glszm_GrayLevelNonUniformityNormalized+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformity                   100 non-null    float64
#  75  wavelet-HHH_firstorder_Uniformity+wavelet-HHH_gldm_GrayLevelVariance+wavelet-HHH_firstorder_Entropy                                                              100 non-null    float64
#  76  square_glszm_SmallAreaLowGrayLevelEmphasis+lbp-3D-m1_firstorder_Median+square_glszm_HighGrayLevelZoneEmphasis                                                    100 non-null    float64
#  77  lbp-2D_firstorder_InterquartileRange+lbp-3D-m1_firstorder_Median+gradient_glcm_MCC                                                                               100 non-null    float64
#  78  log-sigma-5-0-mm-3D_glszm_SmallAreaEmphasis+log-sigma-5-0-mm-3D_glszm_SizeZoneNonUniformityNormalized+wavelet-LLH_glszm_SmallAreaLowGrayLevelEmphasis            100 non-null    float64
#  79  log-sigma-1-0-mm-3D_glcm_ClusterProminence+log-sigma-1-0-mm-3D_firstorder_Maximum+log-sigma-1-0-mm-3D_firstorder_Range                                           100 non-null    float64
#  80  lbp-2D_firstorder_90Percentile+logarithm_glszm_SizeZoneNonUniformityNormalized+logarithm_glszm_SmallAreaEmphasis                                                 100 non-null    float64
#  81  lbp-3D-m1_firstorder_Median+wavelet-LLH_glcm_ClusterShade+gradient_firstorder_Minimum                                                                            100 non-null    float64
#  82  squareroot_glszm_SmallAreaEmphasis+squareroot_glszm_SizeZoneNonUniformityNormalized+wavelet-HHH_glszm_GrayLevelNonUniformityNormalized                           100 non-null    float64
#  83  Sex+lbp-3D-m1_firstorder_Median+wavelet-LHH_glszm_SmallAreaEmphasis                                                                                              100 non-null    float64
#  84  wavelet-HLH_glszm_LowGrayLevelZoneEmphasis+wavelet-HLH_glszm_SmallAreaHighGrayLevelEmphasis+wavelet-HLH_glszm_SmallAreaLowGrayLevelEmphasis                      100 non-null    float64
#  85  wavelet-HLH_firstorder_Minimum+lbp-2D_firstorder_90Percentile+lbp-3D-m1_firstorder_Median                                                                        100 non-null    float64
#  86  wavelet-LLL_glszm_SmallAreaEmphasis+wavelet-LLL_glszm_SizeZoneNonUniformityNormalized+lbp-3D-m1_firstorder_Skewness                                              100 non-null    float64
# dtypes: float64(87)
# memory usage: 68.1 KB
