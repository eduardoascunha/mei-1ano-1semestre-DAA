# %% [markdown]
# # Dados e Aprendizagem Automática
# ### Part V

# %% [markdown]
# ## **I - Feature Engineering using Incidents Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Load the CSV - Incidents*

# %%
incid = pd.read_csv("incidents.csv")

# %% [markdown]
# **EDA**

# %%
incid.columns
# Out:
# Index(['city_name', 'magnitude_of_delay', 'delay_in_seconds', 'affected_roads',
#        'record_date', 'luminosity', 'avg_temperature', 'avg_atm_pressure',
#        'avg_humidity', 'avg_wind_speed', 'avg_precipitation', 'avg_rain',
#        'incidents'],
#       dtype='object')

# %%
incid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city_name           5000 non-null   object
#  1   magnitude_of_delay  5000 non-null   object
#  2   delay_in_seconds    5000 non-null   int64
#  3   affected_roads      4915 non-null   object
#  4   record_date         5000 non-null   object
#  5   luminosity          5000 non-null   object
#  6   avg_temperature     5000 non-null   float64
#  7   avg_atm_pressure    5000 non-null   float64
#  8   avg_humidity        5000 non-null   float64
#  9   avg_wind_speed      5000 non-null   float64
#  10  avg_precipitation   5000 non-null   float64
#  11  avg_rain            5000 non-null   object
#  12  incidents           2972 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 507.9+ KB

# %%
incid.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds  \
# 0  Guimaraes          UNDEFINED                 0
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date  \
# 0                                                  ,  2021-03-15 23:00
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# **Dealing with missing values**

# %%
sns.heatmap(incid.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
incid.isnull().sum()
# Out:
# city_name                0
# magnitude_of_delay       0
# delay_in_seconds         0
# affected_roads          85
# record_date              0
# luminosity               0
# avg_temperature          0
# avg_atm_pressure         0
# avg_humidity             0
# avg_wind_speed           0
# avg_precipitation        0
# avg_rain                 0
# incidents             2028
# dtype: int64

# %%
incid['affected_roads'].head()
# Out:
# 0                                                    ,
# 1                                                N101,
# 2                                                    ,
# 3    N101,R206,N105,N101,N101,N101,N101,N101,N101,N...
# 4                            N101,N101,N101,N101,N101,
# Name: affected_roads, dtype: object

# %%
incid[incid['affected_roads'].isnull()]
# Out:
#       city_name magnitude_of_delay  delay_in_seconds affected_roads  \
# 29    Guimaraes          UNDEFINED                64            NaN
# 76    Guimaraes          UNDEFINED               223            NaN
# 79    Guimaraes              MAJOR                80            NaN
# 91    Guimaraes          UNDEFINED                52            NaN
# 109   Guimaraes          UNDEFINED               139            NaN
# ...         ...                ...               ...            ...
# 4785  Guimaraes              MAJOR               298            NaN
# 4811  Guimaraes          UNDEFINED                96            NaN
# 4838  Guimaraes          UNDEFINED                36            NaN
# 4854  Guimaraes          UNDEFINED               233            NaN
# 4910  Guimaraes          UNDEFINED               324            NaN
#
#            record_date luminosity  avg_temperature  avg_atm_pressure  \
# 29    2021-01-22 09:00      LIGHT              8.0            1012.0
# 76    2021-01-29 08:00      LIGHT             11.0            1022.0
# 79    2021-12-24 21:00       DARK             11.0            1004.0
# 91    2021-03-02 13:00      LIGHT             13.0            1024.0
# 109   2021-12-27 13:00      LIGHT             15.0            1014.0
# ...                ...        ...              ...               ...
# 4785  2021-12-22 13:00      LIGHT             16.0            1015.0
# 4811  2021-03-11 15:00      LIGHT             13.0            1025.0
# 4838  2021-03-10 13:00      LIGHT             14.0            1025.0
# 4854  2021-01-29 20:00       DARK             11.0            1017.0
# 4910  2021-02-03 08:00      LIGHT             10.0            1012.0
#
#       avg_humidity  avg_wind_speed  avg_precipitation     avg_rain incidents
# 29            91.0             4.0                0.0    Sem Chuva    Medium
# 76            92.0             1.0                0.0    Sem Chuva      High
# 79            92.0             0.0                0.0    Sem Chuva       NaN
# 91            78.0             2.0                0.0    Sem Chuva       Low
# 109           88.0             5.0                0.0    Sem Chuva       NaN
# ...            ...             ...                ...          ...       ...
# 4785          71.0             3.0                0.0    Sem Chuva       NaN
# 4811          89.0             3.0                0.0  chuva fraca    Medium
# 4838          65.0             2.0                0.0    Sem Chuva       Low
# 4854          92.0             1.0                0.0    Sem Chuva      High
# 4910          90.0             2.0                0.0    Sem Chuva       Low
#
# [85 rows x 13 columns]

# %% [markdown]
# *Copy data to try different options of handling data*

# %%
incid1 = incid.copy()
incid2 = incid.copy()

# %% [markdown]
# **a) Drop**

# %%
incid1.drop(['affected_roads'], axis = 1, inplace = True)
incid1.head()
# Out:
#    city_name magnitude_of_delay  delay_in_seconds       record_date  \
# 0  Guimaraes          UNDEFINED                 0  2021-03-15 23:00
# 1  Guimaraes          UNDEFINED               385  2021-12-25 18:00
# 2  Guimaraes          UNDEFINED                69  2021-03-12 15:00
# 3  Guimaraes              MAJOR              2297  2021-09-29 09:00
# 4  Guimaraes          UNDEFINED                 0  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# **b) Fill with zero**

# %%
incid2.fillna(0, inplace = True)
incid2.head()
# Out:
#    city_name magnitude_of_delay  delay_in_seconds  \
# 0  Guimaraes          UNDEFINED                 0
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date  \
# 0                                                  ,  2021-03-15 23:00
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva          0
# 1                0.0  Sem Chuva          0
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# We will choose to *drop* the column since it does not bring added value to our goal

# %%
incid.drop(['affected_roads'], axis=1, inplace = True)

# %%
sns.heatmap(incid.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
incid.isnull().sum()
# Out:
# city_name                0
# magnitude_of_delay       0
# delay_in_seconds         0
# record_date              0
# luminosity               0
# avg_temperature          0
# avg_atm_pressure         0
# avg_humidity             0
# avg_wind_speed           0
# avg_precipitation        0
# avg_rain                 0
# incidents             2028
# dtype: int64

# %%
incid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city_name           5000 non-null   object
#  1   magnitude_of_delay  5000 non-null   object
#  2   delay_in_seconds    5000 non-null   int64
#  3   record_date         5000 non-null   object
#  4   luminosity          5000 non-null   object
#  5   avg_temperature     5000 non-null   float64
#  6   avg_atm_pressure    5000 non-null   float64
#  7   avg_humidity        5000 non-null   float64
#  8   avg_wind_speed      5000 non-null   float64
#  9   avg_precipitation   5000 non-null   float64
#  10  avg_rain            5000 non-null   object
#  11  incidents           2972 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 468.9+ KB

# %%
incid.nunique()
# Out:
# city_name                1
# magnitude_of_delay       3
# delay_in_seconds      1186
# record_date           5000
# luminosity               3
# avg_temperature         35
# avg_atm_pressure        36
# avg_humidity            83
# avg_wind_speed          11
# avg_precipitation        1
# avg_rain                 4
# incidents                4
# dtype: int64

# %% [markdown]
# There are features that are of the type <em>object</em>: <em>city_name</em>, <em>magnitude_of_delay</em>, <em>record_date</em>, <em>luminosity</em>, <em>avg_rain</em> and <em>incidents</em>.

# %%
incid["avg_precipitation"].nunique()
# Out:
# 1

# %% [markdown]
# The features <em>city_name</em> and <em>avg_precipitation</em> have only one value. We will start with <em>avg_precipitation</em>:

# %%
incid['avg_precipitation'].describe()
# Out:
# count    5000.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: avg_precipitation, dtype: float64

# %% [markdown]
# Since 0 is the unique value of <em>avg_precipitation</em> and all entries have the same value, we will *drop* this feature

# %%
incid.drop(['avg_precipitation'],axis=1,inplace=True)
incid.head()
# Out:
#    city_name magnitude_of_delay  delay_in_seconds       record_date  \
# 0  Guimaraes          UNDEFINED                 0  2021-03-15 23:00
# 1  Guimaraes          UNDEFINED               385  2021-12-25 18:00
# 2  Guimaraes          UNDEFINED                69  2021-03-12 15:00
# 3  Guimaraes              MAJOR              2297  2021-09-29 09:00
# 4  Guimaraes          UNDEFINED                 0  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#     avg_rain  incidents
# 0  Sem Chuva        NaN
# 1  Sem Chuva        NaN
# 2  Sem Chuva        Low
# 3  Sem Chuva  Very_High
# 4  Sem Chuva       High

# %% [markdown]
# **Handling categoric data**

# %% [markdown]
# Feature <em>city_name</em>

# %%
incid['city_name'].head()
# Out:
# 0    Guimaraes
# 1    Guimaraes
# 2    Guimaraes
# 3    Guimaraes
# 4    Guimaraes
# Name: city_name, dtype: object

# %% [markdown]
# The unique value of <em>city_name</em> is <em>Guimarães</em> - we can *drop* this feature as well

# %%
incid.drop('city_name', axis=1, inplace=True)
incid.dropna(inplace = True)

# %% [markdown]
# Feature <em>incidents</em>

# %%
print(incid['incidents'].value_counts())
# Out:
# incidents
# High         1073
# Low           718
# Very_High     603
# Medium        578
# Name: count, dtype: int64

# %%
print(incid['incidents'].value_counts().count())
# Out:
# 4

# %%
incidents_count = incid['incidents'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x=incidents_count.index, y=incidents_count.values)
plt.title('Frequency Distribution of Incidents')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Incidents', fontsize=12)
plt.show()

# %%
labels = incid['incidents'].astype('category').cat.categories.tolist()
counts = incid['incidents'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis("equal")
plt.show()

# %% [markdown]
# We have several options of how to deal with *qualitative data*:

# %% [markdown]
# **a) Replace Values**

# %%
incid3=incid.copy()
incid3.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2        Low
# 3  Very_High
# 4       High
# 5     Medium
# 6        Low

# %% [markdown]
# Label association: None - 0, Low - 1, Medium - 2, High - 3, Very_High - 4

# %%
replace_map = {'incidents': {'None': 0, 'Low': 1, 'Medium': 2, 'High': 3, 'Very_High': 4}}

# %% [markdown]
# We can create a replacement map in another way:

# %%
labels = incid3['incidents'].astype('category').cat.categories.tolist()
replace_map_comp = {'incidents' : {k: v for k,v in zip(labels, list(range(1,len(labels)+1)))}}
print(replace_map_comp)
# Out:
# {'incidents': {'High': 1, 'Low': 2, 'Medium': 3, 'Very_High': 4}}

# %%
incid3.replace(replace_map_comp, inplace = True)
incid3.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2          2
# 3          4
# 4          1
# 5          3
# 6          2

# %%
print(incid3['incidents'].dtypes)
# Out:
# int64

# %% [markdown]
# **b) Label encoding**

# %%
incid4=incid.copy()

# %%
print(incid4.dtypes)
# Out:
# magnitude_of_delay     object
# delay_in_seconds        int64
# record_date            object
# luminosity             object
# avg_temperature       float64
# avg_atm_pressure      float64
# avg_humidity          float64
# avg_wind_speed        float64
# avg_rain               object
# incidents              object
# dtype: object

# %%
incid4["None"] = np.where(incid4["incidents"].str.contains("None"),1,0)
incid4.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  None
# 2        Low     0
# 3  Very_High     0
# 4       High     0
# 5     Medium     0
# 6        Low     0

# %% [markdown]
# With *LabelEncoder()*:

# %%
incid5=incid.copy()
incid6=incid.copy()

from sklearn.preprocessing import LabelEncoder

le_make = LabelEncoder()
incid5['incidents_code'] = le_make.fit_transform(incid6["incidents"])

incid5.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  incidents_code
# 2        Low               1
# 3  Very_High               3
# 4       High               0
# 5     Medium               2
# 6        Low               1

# %% [markdown]
# **c) One-Hot encoding**

# %%
incid7 = incid.copy()

from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb_results = lb.fit_transform(incid7['incidents'])
lb_results_df = pd.DataFrame(lb_results, columns=lb.classes_)

lb_results_df.head()
# Out:
#    High  Low  Medium  Very_High
# 0     0    1       0          0
# 1     0    0       0          1
# 2     1    0       0          0
# 3     0    0       1          0
# 4     0    1       0          0

# %%
result_df = pd.concat([incid7, lb_results_df],axis=1)
result_df.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED              69.0  2021-03-12 15:00      LIGHT
# 3              MAJOR            2297.0  2021-09-29 09:00      LIGHT
# 4          UNDEFINED               0.0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED               0.0  2021-12-07 23:00       DARK
# 6          UNDEFINED               0.0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  High  Low  Medium  Very_High
# 2        Low   1.0  0.0     0.0        0.0
# 3  Very_High   0.0  0.0     1.0        0.0
# 4       High   0.0  1.0     0.0        0.0
# 5     Medium   1.0  0.0     0.0        0.0
# 6        Low   0.0  0.0     0.0        1.0

# %% [markdown]
# **d) Binary Encoding**

# %% [markdown]
# |   Level   | "Decimal encoding" | Binary encoding | One-Hot encoding |
# | :-------: | :----------------: | :-------------: | :--------------: |
# | None      |         0          |       000       |      000001      |
# | Low       |         1          |       001       |      000010      |
# | Medium    |         2          |       010       |      000100      |
# | High      |         3          |       011       |      001000      |
# | Very_High |         4          |       100       |      010000      |

# %% [markdown]
# For this technique it is needed to have the package <em>category_encoders</em> installed:
#
# <code>!pip install category_encoders</code>

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from category_encoders) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from category_encoders) (1.13.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas>=1.0.5 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from category_encoders) (2.2.2)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 460.0 kB/s eta 0:00:0000:0100:02
# Installing collected packages: patsy, statsmodels, category_encoders
# Successfully installed category_encoders-2.6.4 patsy-0.5.6 statsmodels-0.14.4

# %%
incid8 = incid.copy()

import category_encoders as ce

bencoder = ce.BinaryEncoder(cols=["incidents"])
df_binary = bencoder.fit_transform(incid8)

df_binary.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents_0  incidents_1  incidents_2
# 2            0            0            1
# 3            0            1            0
# 4            0            1            1
# 5            1            0            0
# 6            0            0            1

# %% [markdown]
# **e) Backward difference encoding**

# %%
incid9 = incid.copy()

bde = ce.BackwardDifferenceEncoder(cols=["incidents"])
df_bd = bde.fit_transform(incid9)

df_bd.head()
# Out:
# /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages/category_encoders/base_contrast_encoder.py:126: FutureWarning: Intercept column might not be added anymore in future releases (c.f. issue #370)
#   warnings.warn("Intercept column might not be added anymore in future releases (c.f. issue #370)",
# /home/eduardoascunha/miniconda3/envs/envNAME/lib/python3.12/site-packages/category_encoders/base_contrast_encoder.py:126: FutureWarning: Intercept column might not be added anymore in future releases (c.f. issue #370)
#   warnings.warn("Intercept column might not be added anymore in future releases (c.f. issue #370)",
#    intercept magnitude_of_delay  delay_in_seconds       record_date  \
# 2          1          UNDEFINED                69  2021-03-12 15:00
# 3          1              MAJOR              2297  2021-09-29 09:00
# 4          1          UNDEFINED                 0  2021-06-13 11:00
# 5          1          UNDEFINED                 0  2021-12-07 23:00
# 6          1          UNDEFINED                 0  2021-12-05 05:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
# 5       DARK              9.0            1015.0          94.0             0.0
# 6       DARK              8.0            1026.0          87.0             1.0
#
#     avg_rain  incidents_0  incidents_1  incidents_2
# 2  Sem Chuva        -0.75         -0.5        -0.25
# 3  Sem Chuva         0.25         -0.5        -0.25
# 4  Sem Chuva         0.25          0.5        -0.25
# 5  Sem Chuva         0.25          0.5         0.75
# 6  Sem Chuva        -0.75         -0.5        -0.25

# %% [markdown]
# **f) Factorize**

# %%
incid10 = incid.copy()

# %%
incid10['incidents'] = pd.factorize(incid10['incidents'])[0] + 1
incid10.head()
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1

# %% [markdown]
# We will choose the *factorize* technique to keep going

# %%
incid['incidents'] = pd.factorize(incid['incidents'])[0] + 1

# %% [markdown]
# Regarding the features <em>magnitude_delay</em>, <em>luminosity</em> and <em>avg_rain</em>, we will *factorize* them for now

# %%
incid['magnitude_of_delay'] = pd.factorize(incid['magnitude_of_delay'])[0] + 1
incid['luminosity'] = pd.factorize(incid['luminosity'])[0] + 1
incid['avg_rain'] = pd.factorize(incid['avg_rain'])[0] + 1

incid.head()
# Out:
#    magnitude_of_delay  delay_in_seconds       record_date  luminosity  \
# 2                   1                69  2021-03-12 15:00           1
# 3                   2              2297  2021-09-29 09:00           1
# 4                   1                 0  2021-06-13 11:00           1
# 5                   1                 0  2021-12-07 23:00           2
# 6                   1                 0  2021-12-05 05:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1

# %% [markdown]
# **Handling dates**
#
# *Datetime Properties and Methods* (https://pandas.pydata.org/pandas-docs/version/0.23/api.html#datetimelike-properties)

# %%
incid11 = incid.copy()

# %%
incid11['record_date'].head()
# Out:
# 2    2021-03-12 15:00
# 3    2021-09-29 09:00
# 4    2021-06-13 11:00
# 5    2021-12-07 23:00
# 6    2021-12-05 05:00
# Name: record_date, dtype: object

# %%
incid11['record_date'] = pd.to_datetime(incid11['record_date'],format="%Y-%m-%d %H:%M", errors="coerce")

# %%
assert incid11['record_date'].isnull().sum() == 0, "missing record date"

# %%
incid11['record_date'].head()
# Out:
# 2   2021-03-12 15:00:00
# 3   2021-09-29 09:00:00
# 4   2021-06-13 11:00:00
# 5   2021-12-07 23:00:00
# 6   2021-12-05 05:00:00
# Name: record_date, dtype: datetime64[ns]

# %%
incid11['record_date_year'] = incid11['record_date'].dt.year
incid11['record_date_month'] = incid11['record_date'].dt.month
incid11['record_date_day'] = incid11['record_date'].dt.day
incid11['record_date_hour'] = incid11['record_date'].dt.hour
incid11['record_date_minute'] = incid11['record_date'].dt.minute
incid11.head()
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents  record_date_month  record_date_day  record_date_hour  \
# 2          1                  3               12                15
# 3          2                  9               29                 9
# 4          3                  6               13                11
# 5          4                 12                7                23
# 6          1                 12                5                 5
#
#    record_date_year  record_date_minute
# 2              2021                   0
# 3              2021                   0
# 4              2021                   0
# 5              2021                   0
# 6              2021                   0

# %%
incid11.nunique()
# Out:
# magnitude_of_delay       3
# delay_in_seconds      1167
# record_date           2972
# luminosity               3
# avg_temperature         34
# avg_atm_pressure        34
# avg_humidity            80
# avg_wind_speed          11
# avg_rain                 4
# incidents                4
# record_date_month       11
# record_date_day         31
# record_date_hour        24
# record_date_year         1
# record_date_minute       1
# dtype: int64

# %% [markdown]
# Since the year and the minute have only one value, we will *drop* it

# %%
incid11.drop('record_date_year',axis=1, inplace=True)
incid11.drop('record_date_minute',axis=1, inplace=True)
incid11.drop('record_date',axis=1, inplace=True)
incid11.dropna(inplace=True)

# %%
incid11.head()
# Out:
#    magnitude_of_delay  delay_in_seconds  luminosity  avg_temperature  \
# 2                   1                69           1             14.0
# 3                   2              2297           1             15.0
# 4                   1                 0           1             27.0
# 5                   1                 0           2              9.0
# 6                   1                 0           2              8.0
#
#    avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  incidents  \
# 2            1025.0          64.0             0.0         1          1
# 3            1028.0          75.0             1.0         1          2
# 4            1020.0          52.0             1.0         1          3
# 5            1015.0          94.0             0.0         1          4
# 6            1026.0          87.0             1.0         1          1
#
#    record_date_month  record_date_day  record_date_hour
# 2                  3               12                15
# 3                  9               29                 9
# 4                  6               13                11
# 5                 12                7                23
# 6                 12                5                 5

# %%
incid12 = incid.copy()
incid12['record_date'] = pd.to_datetime(incid12["record_date"])
incid12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2972 entries, 2 to 4995
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_of_delay  2972 non-null   int64
#  1   delay_in_seconds    2972 non-null   int64
#  2   record_date         2972 non-null   datetime64[ns]
#  3   luminosity          2972 non-null   int64
#  4   avg_temperature     2972 non-null   float64
#  5   avg_atm_pressure    2972 non-null   float64
#  6   avg_humidity        2972 non-null   float64
#  7   avg_wind_speed      2972 non-null   float64
#  8   avg_rain            2972 non-null   int64
#  9   incidents           2972 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5)
# memory usage: 319.9 KB

# %%
incid12['record_date'].head()
# Out:
# 2   2021-03-12 15:00:00
# 3   2021-09-29 09:00:00
# 4   2021-06-13 11:00:00
# 5   2021-12-07 23:00:00
# 6   2021-12-05 05:00:00
# Name: record_date, dtype: datetime64[ns]

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2024, 10, 17, 11, 45, 8, 74932)

# %%
today - incid12["record_date"]
# Out:
# 2      1314 days 20:45:08.074932
# 3      1114 days 02:45:08.074932
# 4      1222 days 00:45:08.074932
# 5      1044 days 12:45:08.074932
# 6      1047 days 06:45:08.074932
#                   ...
# 4991   1118 days 17:45:08.074932
# 4992   1257 days 00:45:08.074932
# 4993   1211 days 19:45:08.074932
# 4994   1211 days 13:45:08.074932
# 4995   1283 days 11:45:08.074932
# Name: record_date, Length: 2972, dtype: timedelta64[ns]

# %%
(today - incid12['record_date']).dt.days
# Out:
# 2       1314
# 3       1114
# 4       1222
# 5       1044
# 6       1047
#         ...
# 4991    1118
# 4992    1257
# 4993    1211
# 4994    1211
# 4995    1283
# Name: record_date, Length: 2972, dtype: int64

# %%
incid12['day'] = incid12['record_date'].dt.day
incid12['month'] = incid12['record_date'].dt.month
incid12['hour'] = incid12['record_date'].dt.hour
incid12['time'] = incid12['record_date'].dt.time
incid12.head()
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents  day  month  hour      time
# 2          1   12      3    15  15:00:00
# 3          2   29      9     9  09:00:00
# 4          3   13      6    11  11:00:00
# 5          4    7     12    23  23:00:00
# 6          1    5     12     5  05:00:00

# %%
incid['record_date'] = pd.to_datetime(incid["record_date"], format = '%Y-%m-%d %H:%M', errors='coerce')

# %%
incid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2972 entries, 2 to 4995
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_of_delay  2972 non-null   int64
#  1   delay_in_seconds    2972 non-null   int64
#  2   record_date         2972 non-null   datetime64[ns]
#  3   luminosity          2972 non-null   int64
#  4   avg_temperature     2972 non-null   float64
#  5   avg_atm_pressure    2972 non-null   float64
#  6   avg_humidity        2972 non-null   float64
#  7   avg_wind_speed      2972 non-null   float64
#  8   avg_rain            2972 non-null   int64
#  9   incidents           2972 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5)
# memory usage: 319.9 KB

# %%
incid.head()
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1
